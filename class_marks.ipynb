# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/sukanya-gpt/Downloads/result.csv")
df.info()
df.plot(kind="bar")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SNo.           41 non-null     int64
#  1   Reg No         41 non-null     object
#  2   STUDENT NAME   41 non-null     object
#  3   Sem            41 non-null     int64
#  4   EX-1           41 non-null     int64
#  5   EX-2           41 non-null     int64
#  6   EX-3           41 non-null     int64
#  7   EX-4           41 non-null     int64
#  8   Ex-Total IA-1  41 non-null     int64
#  9   Unnamed: 9     41 non-null     int64
#  10  IA-2           41 non-null     int64
#  11  IA-3           41 non-null     int64
#  12  IA-4           41 non-null     int64
#  13  IA-5           41 non-null     int64
#  14  IA=Total       41 non-null     int64
#  15  Total          41 non-null     int64
#  16  Result         41 non-null     object
# dtypes: int64(14), object(3)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/sukanya-gpt/Downloads/result.csv")
df.info()
plt.scatter(x=df['IA=Total'],y=df['Total'])
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SNo.           41 non-null     int64
#  1   Reg No         41 non-null     object
#  2   STUDENT NAME   41 non-null     object
#  3   Sem            41 non-null     int64
#  4   EX-1           41 non-null     int64
#  5   EX-2           41 non-null     int64
#  6   EX-3           41 non-null     int64
#  7   EX-4           41 non-null     int64
#  8   Ex-Total IA-1  41 non-null     int64
#  9   Unnamed: 9     41 non-null     int64
#  10  IA-2           41 non-null     int64
#  11  IA-3           41 non-null     int64
#  12  IA-4           41 non-null     int64
#  13  IA-5           41 non-null     int64
#  14  IA=Total       41 non-null     int64
#  15  Total          41 non-null     int64
#  16  Result         41 non-null     object
# dtypes: int64(14), object(3)
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['IA-4'])
plt.show()
plt.bar(df['IA=Total'],df['Total'])
plt.show()
